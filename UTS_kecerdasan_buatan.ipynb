# %%
# Data perusahaan
company_detail_list = [
    {
        'name': 'Company 1',
        'domain': 'Retail',
        'country': 'United States'
    },
    {
        'name': 'Company 2',
        'domain': 'Technology',
        'country': 'United Kingdom'
    },
    {
        'name': 'Company 3',
        'domain': 'Healthcare',
        'country': 'United States'
    }
]

# Data karyawan
employee_detail_list = [
    {
        'name': 'EMP-0001',
        'first_name': 'John',
        'last_name': 'Doe',
        'full_name': 'John Doe',
        'company': 'Company 1',
        'nationality': 'Australia'
    },
    {
        'name': 'EMP-0002',
        'first_name': 'Tom',
        'last_name': 'Smith',
        'full_name': 'Tom Smith',
        'company': 'Company 2',
        'nationality': 'United States'
    },
    {
        'name': 'EMP-0003',
        'first_name': 'Andrew',
        'last_name': 'Sebastian',
        'full_name': 'Andrew Sebastian',
        'company': 'Company 3',
        'nationality': 'United States'
    },
    {
        'name': 'EMP-0005',
        'first_name': 'Ying Han',
        'last_name': 'Tan',
        'full_name': 'Ying Han Tan',
        'company': 'Company 1',
        'nationality': 'Australia'
    },
    {
        'name': 'EMP-0015',
        'first_name': 'Kenneth',
        'last_name': 'Ng',
        'full_name': 'Kenneth Ng',
        'company': 'Company 3',
        'nationality': 'United States'
    },
    {
        'name': 'EMP-0018',
        'first_name': 'Rubby',
        'last_name': 'Lee',
        'full_name': 'Rubby Lee',
        'company': 'Company 2',
        'nationality': 'Hong Kong'
    },
    {
        'name': 'EMP-0017',
        'first_name': 'Robert',
        'last_name': 'White',
        'full_name': 'Robert White',
        'company': 'Company 1',
        'nationality': 'United Kingdom'
    }
]

# Task 1: Mendapatkan daftar perusahaan terurut terbalik
def dapatkan_perusahaan_terurut():
    return sorted([{"name": company["name"]} for company in company_detail_list], 
                 key=lambda x: x["name"], 
                 reverse=True)

# Task 2: Mencetak domain perusahaan
def cetak_domain_perusahaan():
    for company in company_detail_list:
        print(f"Company {company['name'].split()[-1]}: {company['domain']} ({company['country']})")

# Task 3: Mendapatkan karyawan per domain
def dapatkan_karyawan_per_domain():
    domain_lookup = {company["name"]: company["domain"] for company in company_detail_list}
    hasil = {company["domain"]: [] for company in company_detail_list}
    
    for employee in employee_detail_list:
        domain = domain_lookup[employee["company"]]
        hasil[domain].append(employee["full_name"])
    
    return hasil

# Task 4: Mendapatkan karyawan dengan negara perusahaan
def dapatkan_karyawan_dengan_negara():
    negara_lookup = {company["name"]: company["country"] for company in company_detail_list}
    
    return [{
        "full_name": employee["full_name"],
        "company": employee["company"],
        "country": negara_lookup[employee["company"]]
    } for employee in employee_detail_list]

# Task 5: Mendapatkan jumlah kewarganegaraan per perusahaan
def dapatkan_jumlah_kewarganegaraan():
    hasil = []
    
    for company in company_detail_list:
        jumlah_kewarganegaraan = {}
        
        for employee in employee_detail_list:
            if employee["company"] == company["name"]:
                nationality = employee["nationality"]
                jumlah_kewarganegaraan[nationality] = jumlah_kewarganegaraan.get(nationality, 0) + 1
        
        hasil.append({
            "company": company["name"],
            "employee_nationality": jumlah_kewarganegaraan
        })
    
    return hasil

# Menjalankan dan mencetak hasil semua tugas
if __name__ == "__main__":
    # Task 1
    print("Hasil Task 1:")
    print(dapatkan_perusahaan_terurut())
    print()

    # Task 2
    print("Hasil Task 2:")
    cetak_domain_perusahaan()
    print()

    # Task 3
    print("Hasil Task 3:")
    print(dapatkan_karyawan_per_domain())
    print()

    # Task 4
    print("Hasil Task 4:")
    print(dapatkan_karyawan_dengan_negara())
    print()

    # Task 5
    print("Hasil Task 5:")
    print(dapatkan_jumlah_kewarganegaraan())
# Out:
# Hasil Task 1:
# [{'name': 'Company 3'}, {'name': 'Company 2'}, {'name': 'Company 1'}]
#
# Hasil Task 2:
# Company 1: Retail (United States)
# Company 2: Technology (United Kingdom)
# Company 3: Healthcare (United States)
#
# Hasil Task 3:
# {'Retail': ['John Doe', 'Ying Han Tan', 'Robert White'], 'Technology': ['Tom Smith', 'Rubby Lee'], 'Healthcare': ['Andrew Sebastian', 'Kenneth Ng']}
#
# Hasil Task 4:
# [{'full_name': 'John Doe', 'company': 'Company 1', 'country': 'United States'}, {'full_name': 'Tom Smith', 'company': 'Company 2', 'country': 'United Kingdom'}, {'full_name': 'Andrew Sebastian', 'company': 'Company 3', 'country': 'United States'}, {'full_name': 'Ying Han Tan', 'company': 'Company 1', 'country': 'United States'}, {'full_name': 'Kenneth Ng', 'company': 'Company 3', 'country': 'United States'}, {'full_name': 'Rubby Lee', 'company': 'Company 2', 'country': 'United Kingdom'}, {'full_name': 'Robert White', 'company': 'Company 1', 'country': 'United States'}]
#
# ...
